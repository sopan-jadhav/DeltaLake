# %% [markdown]
# ## Table Utility Commands

# %%
# %sql
Describe detail deltalakesopan.default.first_table

# %%
# %sql
-- It give much more detailed information about the table
describe extended deltalakesopan.default.first_table

# %% [markdown]
# ## Version of table

# %%
# %sql
Describe history delta.`/Volumes/workspace/default/deltavol/demosink/`

# %% [markdown]
# ## Time travel

# %%
# %sql
RESTORE TABLE deltalakesopan.default.first_table TO VERSION AS OF 0
