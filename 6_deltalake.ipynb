# %% [markdown]
# ##Change Data Feed

# %%
# %sql
alter table deltalakesopan.default.first_table
set tblproperties(delta.enableChangeDataFeed = true)

# %%
# %sql
select * from deltalakesopan.default.first_table

# %%
# %sql
insert into deltalakesopan.default.first_table
values(1,1000),
      (2,2000),
      (3,3000)

# %%
# %sql
update deltalakesopan.default.first_table
set salary = 2000
where id = 1

# %%
# %sql
delete from deltalakesopan.default.first_table
where id = 3

# %%
# %sql
describe history deltalakesopan.default.first_table

# %%
# %sql
select * from table_changes('deltalakesopan.default.first_table', 1)
