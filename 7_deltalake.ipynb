# %% [markdown]
# ##Uniform

# %%
# %sql
-- Delta table with universal fromat can be able to acess different client like apache iceberg and apache hudi
create table deltalakesopan.default.unitbl
using delta tblproperties(
    'delta.enableIcebergCompatV2' = 'true',
    'delta.universalFormat.enabledFormats' = 'iceberg'
)
